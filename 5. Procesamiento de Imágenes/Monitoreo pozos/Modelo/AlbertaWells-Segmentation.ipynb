# %%
# !rm -rf /kaggle/working/.virtual_documents /kaggle/working/oil-gas-well-segmentation

# %%
# !git clone https://github.com/liturriago/oil-gas-well-segmentation.git
# %cd oil-gas-well-segmentation
# !pip install -e . -q
# Out:
# Cloning into 'oil-gas-well-segmentation'...
# remote: Enumerating objects: 395, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 395 (delta 0), reused 2 (delta 0), pack-reused 389 (from 1)
# Receiving objects: 100% (395/395), 2.12 MiB | 14.47 MiB/s, done.
# Resolving deltas: 100% (201/201), done.
# /kaggle/working/oil-gas-well-segmentation
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for oil-gas-well-segmentation (pyproject.toml) ... done

# %%
# !python train.py
# Out:
# [2026-03-24 21:06:17,863][__main__][INFO] - Device: cuda
# [2026-03-24 21:06:17,863][__main__][INFO] - Configuration:
# {'training': {'lr': 0.001, 'batch_size': 32, 'epochs': 50, 'optimizer': 'adam', 'scheduler': 'cosine', 'use_amp': True}, 'model': {'in_channels': 4, 'out_channels': 1, 'encoder': 'resnet34'}, 'loss': {'loss_type': 'focal', 'focal_alpha': 0.75, 'focal_gamma': 2.0, 'dice_weight': 0.0, 'focal_weight': 1.0, 'dice_smooth': 1e-06, 'dice_reduction': 'mean', 'focal_reduction': 'mean'}, 'data': {'train_path': '/kaggle/input/datasets/lucasiturriago/albertawells/train.bin', 'val_path': '/kaggle/input/datasets/lucasiturriago/albertawells/val.bin', 'image_size': 256, 'augmentation': True}, 'metrics': {'threshold': 0.5, 'average': 'macro'}, 'system': {'seed': 42, 'num_workers': 4, 'checkpoint_dir': 'checkpoints', 'log_dir': 'logs'}}
# [Train] Epoch 1: 207it [00:54,  3.77it/s, dice=0.5244, loss=0.0072]
# [Val]   Epoch 1: 45it [00:09,  4.52it/s, dice=0.5388, loss=0.0096]
# ...
